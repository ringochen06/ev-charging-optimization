# %%
import pandas as pd
import folium

# Load the dataset
df = pd.read_csv("../data/NYC_EV_Fleet_Station_Network_20250709.csv")
df.head()

# Quick check
print("Number of stations:", len(df))
print("Column names:", df.columns.tolist())

# Drop rows with missing latitude or longitude
df_clean = df.dropna(subset=["LATITUDE", "LONGITUDE"])

# Initialize base map centered on NYC
nyc_map = folium.Map(location=[40.7128, -74.0060], zoom_start=11)

# Add stations as blue circles
for _, row in df_clean.iterrows():
    folium.CircleMarker(
        location=[row["LATITUDE"], row["LONGITUDE"]],
        radius=3,
        popup=row.get("STATION NAME", ""),
        color="blue",
        fill=True,
        fill_opacity=0.6
    ).add_to(nyc_map)

# Display the map
nyc_map
# Out:
# Number of stations: 1516
# Column names: ['AGENCY', 'STATION NAME', 'TYPE OF CHARGER', 'NO. OF PLUGS', 'ADDRESS', 'CITY', 'POSTCODE', 'BOROUGH', 'PUBLIC CHARGER?', 'FEE FOR CITY DRIVERS', 'LATITUDE', 'LONGITUDE', 'COMMUNITY DISTRICT', 'COUNCIL DISTRICT', 'CENSUS TRACT 2020', 'BIN', 'BBL', 'NEIGHBORHOOD TABULATION AREA (NTA) (2020)']
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3efeaab60763a5ee172f3573b55cb15a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3efeaab60763a5ee172f3573b55cb15a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3efeaab60763a5ee172f3573b55cb15a = L.map(
#                 &quot;map_3efeaab60763a5ee172f3573b55cb15a&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_55fd37733e94f928fa315bd2a7ef7231 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_55fd37733e94f928fa315bd2a7ef7231.addTo(map_3efeaab60763a5ee172f3573b55cb15a);
#
#
#             var circle_marker_7e4de3a8f279f4cf9a60285bc33862f9 = L.circleMarker(
#                 [40.668034, -73.869949],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3efeaab60763a5ee172f3573b55cb15a);
#
#
#         var popup_feeba45c5817b04c1f0c45422564738f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e39e3c4bb9b7ddb58ed4c33dc644a729 = $(`&lt;div id=&quot;html_e39e3c4bb9b7ddb58ed4c33dc644a729&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NYC FLEET / ACS_LINDEN_1_L3&lt;/div&gt;`)[0];
#                 popup_feeba45c5817b04c1f0c45422564738f.setContent(html_e39e3c4bb9b7ddb58ed4c33dc644a729);
#
#
#
#         circle_marker_7e4de3a8f279f4cf9a60285bc33862f9.bindPopup(popup_feeba45c5817b04c1f0c45422564738f)
#         ;
#
#
#
#
#             var circle_marker_4014cf7e968d30585ba9f2300ff35402 = L.circleMarker(
#                 [40.668034, -73.869949],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3efeaab60763a5ee172f3573b55cb15a);
#
#
#         var popup_eae2ade41186362d7ba2d49d5f9c0dfa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_05103f5a26ff08c9ee4fc1f4bc30be52 = $(`&lt;div id=&quot;html_05103f5a26ff08c9ee4fc1f4bc30be52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NYC FLEET / ACS_LINDEN_2_L3&lt;/div&gt;`)[0];
#                 popup_eae2ade41186362d7ba2d49d5f9c0dfa.setContent(html_05103f5a26ff08c9ee4fc1f4bc30be52);
#
#
#
#         circle_marker_4014cf7e968d30585ba9f2300ff35402.bindPopup(popup_eae2ade41186362d7ba2d49d5f9c0dfa)
#         ;
#
#
#
#
#             var circle_marker_3102544ec14edaa060c91d514784dea6 = L.circleMarker(
#                 [40.668034, -73.869949],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3efeaab60763a5ee172f3573b55cb15a);
#
#
#         var popup_6f766e2943eb771152da90d80a1fd811 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f596143e83d43504b41ede79a8fc4fd4 = $(`&lt;div id=&quot;html_f596143e83d43504b41ede79a8fc4fd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NYC FLEET / ACS_LINDEN-1&lt;/div&gt;`)[0];
#                 popup_6f766e2943eb771152da90d80a1fd811.setContent(html_f596143e83d43504b41ede79a8fc4fd4);
#
#
#
#         circle_marker_3102544ec14edaa060c91d514784dea6.bindPopup(popup_6f766e2943eb771152da90d80a1fd811)
#         ;
#
#
#
#
#             var circle_marker_f628de66e
